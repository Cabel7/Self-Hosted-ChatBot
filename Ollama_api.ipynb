# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabel7/web-dev/blob/main/Ollama_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <audio src="https://oobabooga.github.io/silence.m4a" controls>

# %%
# !apt-get update
# !apt-get install -y lshw
# !apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh

# !wget -q https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xzf ngrok-v3-stable-linux-amd64.tgz ngrok

# !./ngrok authtoken <authtoken>

#for story telling
# !ollama serve & ./ngrok http 11434 --host-header="localhost:11434" --log stdout & sleep 5s && ollama run hf.co/DavidAU/Gemma-The-Writer-N-Restless-Quill-10B-Uncensored-GGUF:Q5_K_M
#for better reasoning
# !ollama serve & ./ngrok http 11434 --host-header="localhost:11434" --log stdout & sleep 5s && ollama run hf.co/Andycurrent/gemma-3-4b-it-uncensored-v2-GGUF:Q8_0
